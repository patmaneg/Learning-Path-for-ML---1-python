# %% [markdown]
# <a href="https://colab.research.google.com/github/patmaneg/Learning-Path-for-ML---1-python/blob/master/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x = range(1000)
y = [i **2 for i in x]
plt.plot(x, y)
plt.show()

# %%
# %config InlineBackend.figure_format ='retina'
plt.plot(x,y)
plt.show();
